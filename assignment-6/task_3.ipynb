# %%
import pymongo
from tqdm import tqdm

# constants
additional_data_file = '/Users/rohaan/Desktop/Projects/RIT/CSCI_601_Intro_To_Big_Data/Big-Data-Assignments/assignment-6/additional_data/extra-data.json'
db_name = 'csci_620_ass_4'
collection_name = 'additional_info'
movies_collection = 'Movies'

# code
my_client = pymongo.MongoClient('mongodb://localhost:27017/')
my_db = my_client[f'{db_name}']
add_info_collection = my_db[collection_name]
movies_collection = my_db[movies_collection]

# %%
pipeline = [
    {
        '$lookup': {
            'from': 'Movies', 
            'localField': 'title', 
            'foreignField': 'title', 
            'as': 'title_as_connection'
        }
    }
]

# %%
results = add_info_collection.aggregate(pipeline)

# %%
matches = []
i = 1
results = add_info_collection.aggregate(pipeline)
for result in results:
    result = dict(result)
    if len(result['title_as_connection']) > 0 :
        matches.append(result)
    print('Records processed: ', i)
    i += 1
# Out:
# Records processed:  1
# Records processed:  2
# Records processed:  3
# Records processed:  4
# Records processed:  5
# Records processed:  6
# Records processed:  7
# Records processed:  8
# Records processed:  9
# Records processed:  10
# Records processed:  11
# Records processed:  12
# Records processed:  13
# Records processed:  14
# Records processed:  15
# Records processed:  16
# Records processed:  17
# Records processed:  18
# Records processed:  19
# Records processed:  20
# Records processed:  21
# Records processed:  22
# Records processed:  23
# Records processed:  24
# Records processed:  25
# Records processed:  26
# Records processed:  27
# Records processed:  28
# Records processed:  29
# Records processed:  30
# Records processed:  31
# Records processed:  32
# Records processed:  33
# Records processed:  34
# Records processed:  35
# Records processed:  36
# Records processed:  37
# Records processed:  38
# Records processed:  39
# Records processed:  40
# Records processed:  41
# Records processed:  42
# Records processed:  43
# Records processed:  44
# Records processed:  45
# Records processed:  46
# Records processed:  47
# Records processed:  48
# Records processed:  49
# Records processed:  50
# Records processed:  51
# Records processed:  52
# Records processed:  53
# Records processed:  54
# Records processed:  55
# Records processed:  56
# Records processed:  57
# Records processed:  58
# Records processed:  59
# Records processed:  60
# Records processed:  61
# Records processed:  62
# Records processed:  63
# Records processed:  64
# Records processed:  65
# Records processed:  66
# Records processed:  67
# Records processed:  68
# Records processed:  69
# Records processed:  70
# Records processed:  71
# Records processed:  72
# Records processed:  73
# Records processed:  74
# Records processed:  75
# Records processed:  76
# Records processed:  77
# Records processed:  78
# Records processed:  79
# Records processed:  80
# Records processed:  81
# Records processed:  82
# Records processed:  83
# Records processed:  84
# Records processed:  85
# Records processed:  86
# Records processed:  87
# Records processed:  88
# Records processed:  89
# Records processed:  90
# Records processed:  91
# Records processed:  92
# Records processed:  93
# Records processed:  94
# Records processed:  95
# Records processed:  96
# Records processed:  97
# Records processed:  98
# Records processed:  99
# Records processed:  100
# Records processed:  101
